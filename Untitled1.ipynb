# %% [markdown]
# <a href="https://colab.research.google.com/github/piyushgoutam-lgtm/Engineering-chemistry-programing-assignments/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
humidity = float(input("Enter Relative Humidity (%): "))
temperature = float(input("Enter Temperature (°C): "))
ph = float(input("Enter pH value: "))
salt = input("Is Salt Present? (Yes/No): ").lower()

if humidity > 70 and salt == "yes" and (ph < 6 or ph > 8):
    risk = "High"
elif humidity > 50 or salt == "yes":
    risk = "Moderate"
else:
    risk = "Low"

print("\nCorrosion Risk:", risk)
# Out:
# Enter Relative Humidity (%): 30
# Enter Temperature (°C): 55
# Enter pH value: 6.5
# Is Salt Present? (Yes/No): yes
#
# Corrosion Risk: Moderate
